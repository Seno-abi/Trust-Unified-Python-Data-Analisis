# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
#import statistik
from scipy import stats

# %%
#Import plot
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
uel = 'https://id.wikipedia.org/wiki/Histogram'

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 2.,  4., 10., 16., 17., 14., 19., 12.,  5.,  1.]),
#  array([-2.42528023, -1.92546825, -1.42565628, -0.9258443 , -0.42603233,
#          0.07377965,  0.57359162,  1.0734036 ,  1.57321557,  2.07302755,
#          2.57283952]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2,color='indianred')
# Out:
# (array([ 1.,  3., 12., 10., 20., 14.,  4.,  8.,  4.,  4.]),
#  array([-2.43460849, -1.9258707 , -1.41713291, -0.90839512, -0.39965733,
#          0.10908046,  0.61781825,  1.12655604,  1.63529383,  2.14403162,
#          2.65276941]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,density=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20)
# Out:
# (array([0.04914123, 0.        , 0.04914123, 0.09828246, 0.29484737,
#         0.29484737, 0.29484737, 0.19656491, 0.3439886 , 0.63883597,
#         0.3439886 , 0.3439886 , 0.14742369, 0.04914123, 0.29484737,
#         0.09828246, 0.14742369, 0.04914123, 0.09828246, 0.09828246]),
#  array([-2.43460849, -2.18023959, -1.9258707 , -1.6715018 , -1.41713291,
#         -1.16276401, -0.90839512, -0.65402622, -0.39965733, -0.14528843,
#          0.10908046,  0.36344936,  0.61781825,  0.87218715,  1.12655604,
#          1.38092494,  1.63529383,  1.88966273,  2.14403162,  2.39840052,
#          2.65276941]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex')

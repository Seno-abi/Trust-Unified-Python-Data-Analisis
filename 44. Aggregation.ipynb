# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
df_bir = pd.read_csv('kualitas_bir.csv',sep=';')

# %%
df_bir.head()
# Out:
#    keasaman tetap  keasaman yang mudah menguap  asam sitrat  sisa gula  \
# 0             7.4                         0.70         0.00        1.9
# 1             7.8                         0.88         0.00        2.6
# 2             7.8                         0.76         0.04        2.3
# 3            11.2                         0.28         0.56        1.9
# 4             7.4                         0.70         0.00        1.9
#
#    klorida  sulfur dioksida bebas  sulfur total dioksida  massa jenis    pH  \
# 0    0.076                   11.0                   34.0       0.9978  3.51
# 1    0.098                   25.0                   67.0       0.9968  3.20
# 2    0.092                   15.0                   54.0       0.9970  3.26
# 3    0.075                   17.0                   60.0       0.9980  3.16
# 4    0.076                   11.0                   34.0       0.9978  3.51
#
#    sulfat  alkohol  kualitas
# 0    0.56      9.4         5
# ...

# %%
df_bir['alkohol'].mean()
# Out:
# 10.422983114446502

# %%
df_bir
# Out:
#       keasaman tetap  keasaman yang mudah menguap  asam sitrat  sisa gula  \
# 0                7.4                        0.700         0.00        1.9
# 1                7.8                        0.880         0.00        2.6
# 2                7.8                        0.760         0.04        2.3
# 3               11.2                        0.280         0.56        1.9
# 4                7.4                        0.700         0.00        1.9
# 5                7.4                        0.660         0.00        1.8
# 6                7.9                        0.600         0.06        1.6
# 7                7.3                        0.650         0.00        1.2
# 8                7.8                        0.580         0.02        2.0
# 9                7.5                        0.500         0.36        6.1
# 10               6.7                        0.580         0.08        1.8
# 11               7.5                        0.500         0.36        6.1
# ...

# %%
def max_to_min(arr):
    return arr.max() - arr.min()

# %%
biro = df_bir.groupby('kualitas')

# %%
biro.describe()
# Out:
#          keasaman tetap                                                     \
#                   count      mean       std  min   25%   50%     75%   max
# kualitas
# 3                  10.0  8.360000  1.770875  6.7  7.15  7.50   9.875  11.6
# 4                  53.0  7.779245  1.626624  4.6  6.80  7.50   8.400  12.5
# 5                 681.0  8.167254  1.563988  5.0  7.10  7.80   8.900  15.9
# 6                 638.0  8.347179  1.797849  4.7  7.00  7.90   9.400  14.3
# 7                 199.0  8.872362  1.992483  4.9  7.40  8.80  10.100  15.6
# 8                  18.0  8.566667  2.119656  5.0  7.25  8.25  10.225  12.6
#
#          keasaman yang mudah menguap            ... sulfat       alkohol  \
#                                count      mean  ...    75%   max   count
# kualitas                                        ...
# 3                               10.0  0.884500  ...  0.615  0.86    10.0
# 4                               53.0  0.693962  ...  0.600  2.00    53.0
# ...

# %%
df_bir
# Out:
#       keasaman tetap  keasaman yang mudah menguap  asam sitrat  sisa gula  \
# 0                7.4                        0.700         0.00        1.9
# 1                7.8                        0.880         0.00        2.6
# 2                7.8                        0.760         0.04        2.3
# 3               11.2                        0.280         0.56        1.9
# 4                7.4                        0.700         0.00        1.9
# 5                7.4                        0.660         0.00        1.8
# 6                7.9                        0.600         0.06        1.6
# 7                7.3                        0.650         0.00        1.2
# 8                7.8                        0.580         0.02        2.0
# 9                7.5                        0.500         0.36        6.1
# 10               6.7                        0.580         0.08        1.8
# 11               7.5                        0.500         0.36        6.1
# ...

# %%
biro.agg(max_to_min)
# Out:
#           keasaman tetap  keasaman yang mudah menguap  asam sitrat  sisa gula  \
# kualitas
# 3                    4.9                        1.140         0.66        4.5
# 4                    7.9                        0.900         1.00       11.6
# 5                   10.9                        1.150         0.79       14.3
# 6                    9.6                        0.880         0.78       14.5
# 7                   10.7                        0.795         0.76        7.7
# 8                    7.6                        0.590         0.69        5.0
#
#           klorida  sulfur dioksida bebas  sulfur total dioksida  massa jenis  \
# kualitas
# 3           0.206                   31.0                   40.0      0.00609
# 4           0.565                   38.0                  112.0      0.00760
# 5           0.572                   65.0                  149.0      0.01059
# 6           0.381                   71.0                  159.0      0.01362
# ...

# %%
biro.agg('mean')
# Out:
#           keasaman tetap  keasaman yang mudah menguap  asam sitrat  sisa gula  \
# kualitas
# 3               8.360000                     0.884500     0.171000   2.635000
# 4               7.779245                     0.693962     0.174151   2.694340
# 5               8.167254                     0.577041     0.243686   2.528855
# 6               8.347179                     0.497484     0.273824   2.477194
# 7               8.872362                     0.403920     0.375176   2.720603
# 8               8.566667                     0.423333     0.391111   2.577778
#
#            klorida  sulfur dioksida bebas  sulfur total dioksida  massa jenis  \
# kualitas
# 3         0.122500              11.000000              24.900000     0.997464
# 4         0.090679              12.264151              36.245283     0.996542
# 5         0.092736              16.983847              56.513950     0.997104
# 6         0.084956              15.711599              40.869906     0.996615
# ...

# %%
df_bir.head()
# Out:
#    keasaman tetap  keasaman yang mudah menguap  asam sitrat  sisa gula  \
# 0             7.4                         0.70         0.00        1.9
# 1             7.8                         0.88         0.00        2.6
# 2             7.8                         0.76         0.04        2.3
# 3            11.2                         0.28         0.56        1.9
# 4             7.4                         0.70         0.00        1.9
#
#    klorida  sulfur dioksida bebas  sulfur total dioksida  massa jenis    pH  \
# 0    0.076                   11.0                   34.0       0.9978  3.51
# 1    0.098                   25.0                   67.0       0.9968  3.20
# 2    0.092                   15.0                   54.0       0.9970  3.26
# 3    0.075                   17.0                   60.0       0.9980  3.16
# 4    0.076                   11.0                   34.0       0.9978  3.51
#
#    sulfat  alkohol  kualitas
# 0    0.56      9.4         5
# ...

# %%
df_bir['alk_rank'] = df_bir['kualitas'] / df_bir['alkohol']

# %%
df_bir.head()
# Out:
#    keasaman tetap  keasaman yang mudah menguap  asam sitrat  sisa gula  \
# 0             7.4                         0.70         0.00        1.9
# 1             7.8                         0.88         0.00        2.6
# 2             7.8                         0.76         0.04        2.3
# 3            11.2                         0.28         0.56        1.9
# 4             7.4                         0.70         0.00        1.9
#
#    klorida  sulfur dioksida bebas  sulfur total dioksida  massa jenis    pH  \
# 0    0.076                   11.0                   34.0       0.9978  3.51
# 1    0.098                   25.0                   67.0       0.9968  3.20
# 2    0.092                   15.0                   54.0       0.9970  3.26
# 3    0.075                   17.0                   60.0       0.9980  3.16
# 4    0.076                   11.0                   34.0       0.9978  3.51
#
#    sulfat  alkohol  kualitas  alk_rank
# 0    0.56      9.4         5  0.531915
# ...

# %%
df_bir.pivot_table(index=['kualitas'])
# Out:
#           alk_rank    alkohol  asam sitrat  keasaman tetap  \
# kualitas
# 3         0.303286   9.955000     0.171000        8.360000
# 4         0.392724  10.265094     0.174151        7.779245
# 5         0.507573   9.899706     0.243686        8.167254
# 6         0.569801  10.629519     0.273824        8.347179
# 7         0.614855  11.465913     0.375176        8.872362
# 8         0.668146  12.094444     0.391111        8.566667
#
#           keasaman yang mudah menguap   klorida  massa jenis        pH  \
# kualitas
# 3                            0.884500  0.122500     0.997464  3.398000
# 4                            0.693962  0.090679     0.996542  3.381509
# 5                            0.577041  0.092736     0.997104  3.304949
# 6                            0.497484  0.084956     0.996615  3.318072
# 7                            0.403920  0.076588     0.996104  3.290754
# 8                            0.423333  0.068444     0.995212  3.267222
#
# ...

# %%
# %matplotlib inline

# %%
df_bir.plot(kind='scatter',x='kualitas',y='alkohol')
